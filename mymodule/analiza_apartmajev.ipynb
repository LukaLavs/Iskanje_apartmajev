# %% [markdown]
# # Najprej nastavite parametre v naslednjih celicah
#    - **Navodila najdete v README**

# %%
import main

# %% [markdown]
# ### Opis tabele, ki jo ustvari naslednja celica:
#    - *V tabeli najdete imena apartmajev*
#    - *Ceno v evrih*
#    - *Kapaciteto v obliki *[minimalno število oseb, maksimalno število oseb]**
#    - *Povezavo do apartmaja*

# %%
prihod = "01.08.2024"
odhod = "08.08.2024"
osebe = 4
okolica = "zadar-i-okolica"
kraj = "sukosan"
glavni_naslov = "rogoznica"
tip_urlja = 2

df_vsi_apartmaji = main.ustvari_df_glavne_strani(prihod, odhod, osebe, okolica, kraj, glavni_naslov, tip_urlja)
df_vsi_apartmaji
# Out:
#                        Ime   Cena Kapaciteta  \
# 123         Apartmani Mima   25.0    [2, 14]
# 50        Apartmani Katica   30.0    [2, 29]
# 53         Apartmani  Ines   35.0    [2, 20]
# 17     Apartmani Iva Janeš   35.0    [2, 12]
# 67       Apartmani Maslina   35.0    [2, 15]
# ..                     ...    ...        ...
# 121         Apartmani Rora  110.0    [4, 16]
# 43           Apartman Blue  130.0     [4, 6]
# 5    Apartmani Villa Marin  150.0    [4, 12]
# 132         Villa Martinis  250.0     [5, 5]
# 131           Villa Zdenka  280.0   [12, 12]
#
#                                               Povezava
# 123  https://www.apartmanija.hr/apartmani/rogoznica...
# 50   https://www.apartmanija.hr/apartmani/rogoznica...
# 53   https://www.apartmanija.hr/apartmani/rogoznica...
# 17   https://www.apartmanija.hr/apartmani/rogoznica...
# 67   https://www.apartmanija.hr/apartmani/rogoznica...
# ..                                                 ...
# ...

# %% [markdown]
# ### Opis tabele, ki jo ustvari naslednja celica:
#    - *Tabela je urejena, najprej po tipu sobe, nato po cenah, potem pa po oddaljenosti do plaže.*
#    - *V tabeli najdete imena apartmajev, točne naslove in več*
#    - *Cene so v evrih*
#    - *Razdalje pa v metrih*

# %%
podrobna_analiza = 60
#brskalnik = "chrome"
#brskalnik = "edge"
brskalnik = "firefox"

df_par_apartmajev_natancno = main.ustvari_podroben_csv(df_vsi_apartmaji, podrobna_analiza, prihod, odhod, brskalnik)
df_par_apartmajev_natancno
# Out:
#                       Ime                               Naslov      Soba  \
# 6        Apartmani Katica  Stupin Čeline| Ždrilo 29| Rogoznica        A2
# 10        Apartmani  Ines        Lozica IV| kuca 52| Rogoznica        A2
# 13        Apartmani  Ines        Lozica IV| kuca 52| Rogoznica        A2
# 122       Apartmani Braco                 Ždrilo 22| Rogoznica        A2
# 143        Apartmani Šime                Miline 54a| Rogoznica        A2
# ..                    ...                                  ...       ...
# 128  Apartmani Vila Luxor           Put Šepurine 22| Rogoznica  Studio+2
# 126  Apartmani Vila Luxor           Put Šepurine 22| Rogoznica  Studio+2
# 84         Apartmani Dino            Stupin Čeline | Rogoznica  Studio+2
# 38        Apartmani Ivona             Zečevarska 39| Rogoznica  Studio+2
# 79         Apartman Marin          Stupin Čeline 49| Rogoznica  Studio+2
#
#      Skupna cena  Cena na noč  Morje  Plaža Center Trgovina Restavracija  \
# ...

# %% [markdown]
# ### Opis naslednje celice:
#    - *Celica ustvari nekaj morebiti zanimivih grafov*

# %%
main.graf(df_par_apartmajev_natancno)
