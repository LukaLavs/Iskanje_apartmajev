# %%
import main

# %% [markdown]
# V naslednji celici vpišite željen datum prihoda, odhoda, željeno
# število oseb in vrednost i glede na tip url-ja. Prav tako vpišite
# okolico in točen kraj oziroma le glavni_naslov. Bodite pozorni,
# da so parametri v taki obliki, da tvorijo veljaven url.
# Za podrobnejša navodila odprite README.
# Celica ustvari tabelo vseh apartmajev.

# %%
prihod = "01.08.2024"
odhod = "08.08.2024"
osebe = 4
okolica = "zadar-i-okolica"
kraj = "sukosan"
glavni_naslov = "rogoznica"
tip_urlja = 2

df_vsi_apartmaji = main.ustvari_df_glavne_strani(prihod, odhod, osebe, okolica, kraj, glavni_naslov, tip_urlja)
df_vsi_apartmaji
# Out:
#                        Ime   Cena Kapaciteta  \
# 123         Apartmani Mima   25.0    [2, 14]
# 50        Apartmani Katica   30.0    [2, 29]
# 53         Apartmani  Ines   35.0    [2, 20]
# 17     Apartmani Iva Janeš   35.0    [2, 12]
# 67       Apartmani Maslina   35.0    [2, 15]
# ..                     ...    ...        ...
# 121         Apartmani Rora  110.0    [4, 16]
# 43           Apartman Blue  130.0     [4, 6]
# 5    Apartmani Villa Marin  150.0    [4, 12]
# 132         Villa Martinis  250.0     [5, 5]
# 131           Villa Zdenka  280.0   [12, 12]
#
#                                               Povezava
# 123  https://www.apartmanija.hr/apartmani/rogoznica...
# 50   https://www.apartmanija.hr/apartmani/rogoznica...
# 53   https://www.apartmanija.hr/apartmani/rogoznica...
# 17   https://www.apartmanija.hr/apartmani/rogoznica...
# 67   https://www.apartmanija.hr/apartmani/rogoznica...
# ..                                                 ...
# 121  https://www.apartmanija.hr/apartmani/rogoznica...
# 43   https://www.apartmanija.hr/apartmani/rogoznica...
# 5    https://www.apartmanija.hr/apartmani/rogoznica...
# 132  https://www.apartmanija.hr/vile/rogoznica/vill...
# 131  https://www.apartmanija.hr/vile/rogoznica/vill...
#
# [133 rows x 4 columns]

# %% [markdown]
# V naslednji celici vpišite koliko apartmajev želite podrobneje pogledati,
# če ni na voljo toliko apartmajev, podrobneje pogledamo vse. Vpišite tudi brskalnik,
# ki ga uporabljate, podprti so Firefox, Chrome in Edge. Velikost črk pri pisanju imena ni pomembna.
# Celica ustvari tabelo z vsemi sobami, ki so na voljo. Tabela je urejena,
# najprej po tipu sobe, nato po cenah, potem pa po oddaljenosti do plaže.

# %%
podrobna_analiza = 60
brskalnik = "chrome"
#brskalnik = "edge"
#brskalnik = "firefox"

df_par_apartmajev_natancno = main.ustvari_podroben_csv(df_vsi_apartmaji, podrobna_analiza, prihod, odhod, brskalnik)
df_par_apartmajev_natancno
# Out:
#               Ime                         Naslov    Soba  Skupna cena  \
# 0  Apartmani Mima  Put Starog Sela 12| Rogoznica    A4+1        640.0
# 1  Apartmani Mima  Put Starog Sela 12| Rogoznica    A4+1        640.0
# 3  Apartmani Mima  Put Starog Sela 12| Rogoznica  Studio        280.0
# 2  Apartmani Mima  Put Starog Sela 12| Rogoznica  Studio        440.0
#
#    Cena na noč  Morje  Plaža  Center  Trgovina  Restavracija  \
# 0         80.0     80    100    1000       100           700
# 1         80.0     80    100    1000       100           700
# 3         35.0     80    100    1000       100           700
# 2         55.0     80    100    1000       100           700
#
#                                             Povezava
# 0  https://www.apartmanija.hr/apartmani/rogoznica...
# 1  https://www.apartmanija.hr/apartmani/rogoznica...
# 3  https://www.apartmanija.hr/apartmani/rogoznica...
# 2  https://www.apartmanija.hr/apartmani/rogoznica...

# %% [markdown]
# Naslednja celica shrani nekaj zanimivih grafičnih prikazov v datoteko grafi_in_tabele. Grafi predstavijo ravno tisto kar jim piše v naslovu.

# %%
main.graf(df_par_apartmajev_natancno)
